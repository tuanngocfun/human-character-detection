# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/5c/e9/ee572691a3fb05555bcde41826faad29ae4bc1fb07982e7f53d54a176879/scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.17.3 in /home/ngoc/anaconda3/envs/labelImg/lib/python3.10/site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: scipy>=1.5.0 in /home/ngoc/anaconda3/envs/labelImg/lib/python3.10/site-packages (from scikit-learn) (1.9.3)
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Obtaining dependency information for joblib>=1.1.1 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 318.6 kB/s eta 0:00:0000:0100:01
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 482.8 kB/s eta 0:00:00a 0:00:01
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# DEPRECATION: wfuzz 3.1.0 has a non-standard dependency specifier pyparsing>=2.4*; python_version >= "3.5". pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of wfuzz or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.0 threadpoolctl-3.2.0

# %%
import os
from collections import defaultdict

def count_files_with_same_extension(directory):
    extension_count = defaultdict(lambda: defaultdict(int))

    for root, dirs, files in os.walk(directory):
        for file in files:
            try:
                file_extension = os.path.splitext(file)[1]
                extension_count[root][file_extension] += 1
            except PermissionError:
                print(f"Permission denied: {os.path.join(root, file)}, skipping this file.")
            except Exception as e:
                print(f"Error occurred: {e}. Skipping this file.")
    return extension_count

def print_extension_counts(extension_count):
    for dir_path, extensions in extension_count.items():
        print(dir_path + ":")
        for ext, count in extensions.items():
            print(f"- with {ext} files: {count}")

def main():
    try:
        directory = '/media/ngoc/mydisk/ngoc/thesis/data/filter-frame'
        if not os.path.exists(directory):
            print("Invalid directory path. Please ensure the directory exists.")
            return
        extension_count = count_files_with_same_extension(directory)
        print_extension_counts(extension_count)
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# /media/ngoc/mydisk/ngoc/thesis/data/filter-frame:
# - with .jpg files: 4501

# %%
import os
from collections import defaultdict

def count_files_with_same_extension(directory):
    extension_count = defaultdict(lambda: defaultdict(int))

    for root, dirs, files in os.walk(directory):
        for file in files:
            try:
                file_extension = os.path.splitext(file)[1]
                extension_count[root][file_extension] += 1
            except PermissionError:
                print(f"Permission denied: {os.path.join(root, file)}, skipping this file.")
            except Exception as e:
                print(f"Error occurred: {e}. Skipping this file.")
    return extension_count

def print_extension_counts(extension_count):
    for dir_path, extensions in extension_count.items():
        print(dir_path + ":")
        for ext, count in extensions.items():
            print(f"- with {ext} files: {count}")

def main():
    try:
        directory = 'data/filter-frame-similarity-groups'
        if not os.path.exists(directory):
            print("Invalid directory path. Please ensure the directory exists.")
            return
        extension_count = count_files_with_same_extension(directory)
        print_extension_counts(extension_count)
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# data/filter-frame-similarity-groups:
# - with .jpg files: 7462

# %%
import shutil
import glob

source_directory = 'filter-frame-similarity-groups/'
target_directory = 'filter-frame/'

import os
if not os.path.exists(target_directory):
    os.makedirs(target_directory)

jpg_files = glob.glob(f'{source_directory}*.jpg')

for file in jpg_files:
    shutil.move(file, target_directory)

print(f"Moved {len(jpg_files)} .jpg files from {source_directory} to {target_directory}")
# Out:
# Moved 1707 .jpg files from filter-frame-similarity-groups/ to filter-frame/

# %%
from sklearn.metrics.pairwise import cosine_similarity
from PIL import Image
import os
import shutil
import numpy as np

# Define the directories
source_dir = '/media/ngoc/mydisk/ngoc/thesis/data/filter-frame'
target_dir = '/media/ngoc/mydisk/ngoc/thesis/data/filter-frame-similarity-groups'

# Create the target directory if it doesn't exist
if not os.path.exists(target_dir):
    os.makedirs(target_dir)

# Function to convert image to vector
def image_to_vector(image_path):
    image = Image.open(image_path)
    image = image.resize((100, 100)) # resizing the image
    return np.array(image).flatten()

# Read images and convert to vectors
image_vectors = []
image_paths = []
for filename in os.listdir(source_dir):
    if filename.endswith(".jpg"):
        image_path = os.path.join(source_dir, filename)
        image_paths.append(image_path)
        image_vectors.append(image_to_vector(image_path))

# Calculate similarities and group images
threshold = 0.9 # similarity threshold
groups = []
while image_vectors:
    first_image = image_vectors.pop(0)
    group = [image_paths.pop(0)]
    i = 0
    while i < len(image_vectors):
        vector = image_vectors[i]
        similarity = cosine_similarity([first_image], [vector])
        if similarity >= threshold:
            group.append(image_paths.pop(i))
            image_vectors.pop(i)
        else:
            i += 1
    groups.append(group)

# Move the similar images to the target directory, retaining the first in each group
for group in groups:
    for image_path in group[1:]: # Skip the first image in the group
        shutil.move(image_path, os.path.join(target_dir, os.path.basename(image_path)))

print("Similarity filtering and grouping is complete.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 39
#      37 while i < len(image_vectors):
#      38     vector = image_vectors[i]
# ---> 39     similarity = cosine_similarity([first_image], [vector])
#      40     if similarity >= threshold:
#      41         group.append(image_paths.pop(i))
#
# File ~/anaconda3/envs/labelImg/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/anaconda3/envs/labelImg/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:1577, in cosine_similarity(X, Y, dense_output)
#    1542 """Compute cosine similarity between samples in X and Y.
#    1543
#    1544 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1573     Returns the cosine similarity between samples in X and Y.
#    1574 """
#    1575 # to avoid recursive import
# -> 1577 X, Y = check_pairwise_arrays(X, Y)
#    1579 X_normalized = normalize(X, copy=True)
#    1580 if X is Y:
#
# File ~/anaconda3/envs/labelImg/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:165, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     156     X = Y = check_array(
#     157         X,
#     158         accept_sparse=accept_sparse,
#    (...)
#     162         estimator=estimator,
#     163     )
#     164 else:
# --> 165     X = check_array(
#     166         X,
#     167         accept_sparse=accept_sparse,
#     168         dtype=dtype,
#     169         copy=copy,
#     170         force_all_finite=force_all_finite,
#     171         estimator=estimator,
#     172     )
#     173     Y = check_array(
#     174         Y,
#     175         accept_sparse=accept_sparse,
#    (...)
#     179         estimator=estimator,
#     180     )
#     182 if precomputed:
#
# File ~/anaconda3/envs/labelImg/lib/python3.10/site-packages/sklearn/utils/validation.py:824, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     821     else:
#     822         dtype = None
# --> 824 if isinstance(dtype, (list, tuple)):
#     825     if dtype_orig is not None and dtype_orig in dtype:
#     826         # no dtype conversion required
#     827         dtype = None
#
# KeyboardInterrupt:

# %% [markdown]
# cpu resources

# %%
from concurrent.futures import ProcessPoolExecutor
from sklearn.metrics.pairwise import cosine_similarity
from PIL import Image
import os
import shutil
import numpy as np

# Define the directories
source_dir = 'filter-frame'
target_dir = 'filter-frame-similarity-groups'

# Create the target directory if it doesn't exist
if not os.path.exists(target_dir):
    os.makedirs(target_dir)

# Function to convert image to vector
def image_to_vector(image_path):
    image = Image.open(image_path)
    image = image.resize((100, 100)) # resizing the image
    return np.array(image).flatten()

# Read images and convert to vectors
image_vectors = []
image_paths = []
for filename in os.listdir(source_dir):
    if filename.endswith(".jpg"):
        image_path = os.path.join(source_dir, filename)
        image_paths.append(image_path)
        image_vectors.append(image_to_vector(image_path))

# Function to find similar images
def find_similar_images(first_image, vectors, paths, threshold=0.9):
    group = []
    for i, vector in enumerate(vectors):
        similarity = cosine_similarity([first_image], [vector])
        if similarity >= threshold:
            group.append(paths[i])
    return group

# Parallelize finding similar images using all CPU cores
groups = []
with ProcessPoolExecutor() as executor:
    for i, result in enumerate(executor.map(find_similar_images, image_vectors, [image_vectors]*len(image_vectors), [image_paths]*len(image_paths))):
        groups.append([image_paths[i]] + result)

# Move the similar images to the target directory, retaining the first in each group
for group in groups:
    for image_path in group[1:]: # Skip the first image in the group
        shutil.move(image_path, os.path.join(target_dir, os.path.basename(image_path)))

print("Similarity filtering and grouping is complete.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 43
#      41 groups = []
#      42 with ProcessPoolExecutor() as executor:
# ---> 43     for i, result in enumerate(executor.map(find_similar_images, image_vectors, [image_vectors]*len(image_vectors), [image_paths]*len(image_paths))):
#      44         groups.append([image_paths[i]] + result)
#      46 # Move the similar images to the target directory, retaining the first in each group
#
# File ~/miniconda3/envs/faiss/lib/python3.10/concurrent/futures/process.py:575, in _chain_from_iterable_of_lists(iterable)
#     569 def _chain_from_iterable_of_lists(iterable):
#     570     """
#     571     Specialized implementation of itertools.chain.from_iterable.
#     572     Each item in *iterable* should be a list.  This function is
#     573     careful not to keep references to yielded objects.
#     574     """
# --> 575     for element in iterable:
#     576         element.reverse()
#     577         while element:
#
# File ~/miniconda3/envs/faiss/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/miniconda3/envs/faiss/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File ~/miniconda3/envs/faiss/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File ~/miniconda3/envs/faiss/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# reshape the vector to 2d, skip the first image in similarity group

# %%
from concurrent.futures import ProcessPoolExecutor
from sklearn.metrics.pairwise import cosine_similarity
from PIL import Image
import os
import shutil
import numpy as np

source_dir = 'filter-frame'
target_dir = 'filter-frame-similarity-groups'

if not os.path.exists(target_dir):
    os.makedirs(target_dir)

def image_to_vector(image_path):
    image = Image.open(image_path)
    image = image.resize((100, 100))
    return np.array(image).flatten().reshape(1, -1) # Reshape the vector

image_vectors = []
image_paths = []
for filename in os.listdir(source_dir):
    if filename.endswith(".jpg"):
        image_path = os.path.join(source_dir, filename)
        image_paths.append(image_path)
        image_vectors.append(image_to_vector(image_path))

def find_similar_images(first_image, vectors, paths, threshold=0.9):
    group = []
    for i, vector in enumerate(vectors):
        if i == 0: continue # Skip the first image itself
        similarity = cosine_similarity(first_image, vector) # Directly use the reshaped vector
        if similarity[0][0] >= threshold:
            group.append(paths[i])
    return group

groups = []
with ProcessPoolExecutor(max_workers=24) as executor:
    for i, result in enumerate(executor.map(find_similar_images, image_vectors, [image_vectors]*len(image_vectors), [image_paths]*len(image_paths))):
        groups.append([image_paths[i]] + result)

for group in groups:
    for image_path in group[1:]: # Start from the second image in the group
        if os.path.exists(image_path):
            try:
                shutil.move(image_path, os.path.join(target_dir, os.path.basename(image_path)))
                print(f"Successfully moved similar image: {image_path}") # Logging
            except Exception as e:
                print(f"Failed to move {image_path}: {str(e)}")
        else:
            print(f"Source file not found: {image_path}")

print("Similarity filtering and grouping is complete.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 38
#      36 groups = []
#      37 with ProcessPoolExecutor(max_workers=24) as executor:
# ---> 38     for i, result in enumerate(executor.map(find_similar_images, image_vectors, [image_vectors]*len(image_vectors), [image_paths]*len(image_paths))):
#      39         groups.append([image_paths[i]] + result)
#      41 for group in groups:
#
# File ~/miniconda3/envs/faiss/lib/python3.10/concurrent/futures/process.py:575, in _chain_from_iterable_of_lists(iterable)
#     569 def _chain_from_iterable_of_lists(iterable):
#     570     """
#     571     Specialized implementation of itertools.chain.from_iterable.
#     572     Each item in *iterable* should be a list.  This function is
#     573     careful not to keep references to yielded objects.
#     574     """
# --> 575     for element in iterable:
#     576         element.reverse()
#     577         while element:
#
# File ~/miniconda3/envs/faiss/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/miniconda3/envs/faiss/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File ~/miniconda3/envs/faiss/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File ~/miniconda3/envs/faiss/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# max cpu

# %%
from concurrent.futures import ProcessPoolExecutor
from sklearn.metrics.pairwise import cosine_similarity
from PIL import Image
import os
import shutil
import numpy as np
import logging

source_dir = 'data/filter-frame'
target_dir = 'data/filter-frame-similarity-groups'
threshold = 0.9
image_size = (100, 100)
max_workers = 24

logging.basicConfig(level=logging.INFO)

if not os.path.exists(target_dir):
    os.makedirs(target_dir)

def image_to_vector(image_path):
    try:
        with Image.open(image_path).convert('RGB') as image:
            image = image.resize(image_size)
            return np.array(image).flatten()
    except Exception as e:
        logging.error(f"Failed to process {image_path}: {str(e)}")
        return None

def process_images(image_paths):
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        vectors = list(executor.map(image_to_vector, image_paths))
    return [v for v in vectors if v is not None]

image_paths = [os.path.join(source_dir, filename) for filename in os.listdir(source_dir) if filename.endswith(".jpg")]
image_vectors = process_images(image_paths)

similarities = cosine_similarity(image_vectors)
processed_images = np.zeros(len(image_paths), dtype=bool)

for i in range(len(image_vectors)):
    if processed_images[i]:
        continue

    group = [j for j in range(len(image_vectors)) if similarities[i][j] >= threshold and not processed_images[j]]
    for j in group:
        processed_images[j] = True

    first_image = image_paths[i]
    for j in group[1:]:
        source_path = image_paths[j]
        target_path = os.path.join(target_dir, os.path.basename(source_path))
        logging.info(f"Moving from {source_path} to {target_path}")
        if os.path.exists(source_path):
            try:
                shutil.move(source_path, target_path)
            except Exception as e:
                logging.error(f"Failed to move {source_path}: {str(e)}")
        else:
            logging.error(f"Source file not found: {source_path}")

logging.info("Similarity filtering and grouping is complete.")

# %% [markdown]
# retain the first image in similarity group

# %%
from concurrent.futures import ProcessPoolExecutor
from sklearn.metrics.pairwise import cosine_similarity
from PIL import Image
import os
import shutil
import numpy as np
import logging

source_dir = 'data/filter-frame'
target_dir = 'data/filter-frame-similarity-groups'
threshold = 0.9
image_size = (100, 100)
max_workers = 24

logging.basicConfig(level=logging.INFO)

if not os.path.exists(target_dir):
    os.makedirs(target_dir)

def image_to_vector(image_path):
    try:
        with Image.open(image_path).convert('RGB') as image:
            image = image.resize(image_size)
            return np.array(image).flatten()
    except Exception as e:
        logging.error(f"Failed to process {image_path}: {str(e)}")
        return None

def process_images(image_paths):
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        vectors = list(executor.map(image_to_vector, image_paths))
    return [v for v in vectors if v is not None]

image_paths = [os.path.join(source_dir, filename) for filename in os.listdir(source_dir) if filename.endswith(".jpg")]
image_vectors = process_images(image_paths)

similarities = cosine_similarity(image_vectors)
processed_images = np.zeros(len(image_paths), dtype=bool)

for i in range(len(image_vectors)):
    if processed_images[i]:
        continue

    group = [j for j in range(len(image_vectors)) if similarities[i][j] >= threshold and not processed_images[j]]
    for j in group[1:]: # Skip the first image in the group
        processed_images[j] = True

        source_path = image_paths[j]
        target_path = os.path.join(target_dir, os.path.basename(source_path))
        logging.info(f"Moving from {source_path} to {target_path}")
        if os.path.exists(source_path):
            try:
                shutil.move(source_path, target_path)
            except Exception as e:
                logging.error(f"Failed to move {source_path}: {str(e)}")
        else:
            logging.error(f"Source file not found: {source_path}")

logging.info("Similarity filtering and grouping is complete.")
# Out:
# INFO:root:Moving from data/filter-frame/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_1148.jpg to data/filter-frame-similarity-groups/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_1148.jpg
# INFO:root:Moving from data/filter-frame/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_938.jpg to data/filter-frame-similarity-groups/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_938.jpg
# INFO:root:Moving from data/filter-frame/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_935.jpg to data/filter-frame-similarity-groups/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_935.jpg
# INFO:root:Moving from data/filter-frame/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_933.jpg to data/filter-frame-similarity-groups/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_933.jpg
# INFO:root:Moving from data/filter-frame/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_936.jpg to data/filter-frame-similarity-groups/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_936.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_18.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_18.jpg
# INFO:root:Moving from data/filter-frame/Best Of Beavis & Butthead (Part 12)_frame_304.jpg to data/filter-frame-similarity-groups/Best Of Beavis & Butthead (Part 12)_frame_304.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_246.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_246.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_60.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_60.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_249.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_249.jpg
# INFO:root:Moving from data/filter-frame/Best Of Beavis & Butthead (Part 12)_frame_301.jpg to data/filter-frame-similarity-groups/Best Of Beavis & Butthead (Part 12)_frame_301.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_1627.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_1627.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_BnR--12_End_720p_frame_199.jpg to data/filter-frame-similarity-groups/Otakudesu_BnR--12_End_720p_frame_199.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_705.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_705.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_532.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_532.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_575.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_575.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.io_Komisan--12_End_720p_frame_120.jpg to data/filter-frame-similarity-groups/Otakudesu.io_Komisan--12_End_720p_frame_120.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.io_Komisan--12_End_720p_frame_704.jpg to data/filter-frame-similarity-groups/Otakudesu.io_Komisan--12_End_720p_frame_704.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_1190.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_1190.jpg
# INFO:root:Moving from data/filter-frame/Rick and Morty Season 01 Episode 01 Ending_frame_45.jpg to data/filter-frame-similarity-groups/Rick and Morty Season 01 Episode 01 Ending_frame_45.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_671.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_671.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.io_Komisan--12_End_720p_frame_1508.jpg to data/filter-frame-similarity-groups/Otakudesu.io_Komisan--12_End_720p_frame_1508.jpg
# INFO:root:Moving from data/filter-frame/MASH-UP Ready to Play Bring Out Your Beast  Craig of The Creek  Cartoon Network_frame_5.jpg to data/filter-frame-similarity-groups/MASH-UP Ready to Play Bring Out Your Beast  Craig of The Creek  Cartoon Network_frame_5.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_1609.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_1609.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_BnR--12_End_720p_frame_967.jpg to data/filter-frame-similarity-groups/Otakudesu_BnR--12_End_720p_frame_967.jpg
# INFO:root:Moving from data/filter-frame/Best Of Beavis & Butthead (Part 12)_frame_84.jpg to data/filter-frame-similarity-groups/Best Of Beavis & Butthead (Part 12)_frame_84.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_29.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_29.jpg
# INFO:root:Moving from data/filter-frame/Best Of Beavis & Butthead (Part 12)_frame_77.jpg to data/filter-frame-similarity-groups/Best Of Beavis & Butthead (Part 12)_frame_77.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_GJ-bu--12_End_720p_frame_773.jpg to data/filter-frame-similarity-groups/Otakudesu_GJ-bu--12_End_720p_frame_773.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_BnR--12_End_720p_frame_57.jpg to data/filter-frame-similarity-groups/Otakudesu_BnR--12_End_720p_frame_57.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_BnR--12_End_720p_frame_952.jpg to data/filter-frame-similarity-groups/Otakudesu_BnR--12_End_720p_frame_952.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_186.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_186.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_GJ-bu--12_End_720p_frame_763.jpg to data/filter-frame-similarity-groups/Otakudesu_GJ-bu--12_End_720p_frame_763.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_BnR--12_End_720p_frame_198.jpg to data/filter-frame-similarity-groups/Otakudesu_BnR--12_End_720p_frame_198.jpg
# INFO:root:Moving from data/filter-frame/All Out - Tackle Highlight_frame_10.jpg to data/filter-frame-similarity-groups/All Out - Tackle Highlight_frame_10.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_1630.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_1630.jpg
# INFO:root:Moving from data/filter-frame/All Out - Tackle Highlight_frame_18.jpg to data/filter-frame-similarity-groups/All Out - Tackle Highlight_frame_18.jpg
# INFO:root:Moving from data/filter-frame/Best Of Beavis & Butthead (Part 12)_frame_306.jpg to data/filter-frame-similarity-groups/Best Of Beavis & Butthead (Part 12)_frame_306.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.io_Komisan--12_End_720p_frame_675.jpg to data/filter-frame-similarity-groups/Otakudesu.io_Komisan--12_End_720p_frame_675.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.io_Komisan--12_End_720p_frame_835.jpg to data/filter-frame-similarity-groups/Otakudesu.io_Komisan--12_End_720p_frame_835.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_392.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_392.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_1775.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_1775.jpg
# INFO:root:Moving from data/filter-frame/Best Of Beavis & Butthead (Part 12)_frame_179.jpg to data/filter-frame-similarity-groups/Best Of Beavis & Butthead (Part 12)_frame_179.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_463.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_463.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_252.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_252.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_GJ-bu--12_End_720p_frame_767.jpg to data/filter-frame-similarity-groups/Otakudesu_GJ-bu--12_End_720p_frame_767.jpg
# INFO:root:Moving from data/filter-frame/Rick and Morty Season 01 Episode 01 Ending_frame_49.jpg to data/filter-frame-similarity-groups/Rick and Morty Season 01 Episode 01 Ending_frame_49.jpg
# INFO:root:Moving from data/filter-frame/MASH-UP Ready to Play Bring Out Your Beast  Craig of The Creek  Cartoon Network_frame_390.jpg to data/filter-frame-similarity-groups/MASH-UP Ready to Play Bring Out Your Beast  Craig of The Creek  Cartoon Network_frame_390.jpg
# INFO:root:Moving from data/filter-frame/Best Of Beavis & Butthead (Part 12)_frame_120.jpg to data/filter-frame-similarity-groups/Best Of Beavis & Butthead (Part 12)_frame_120.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.io_Komisan--12_End_720p_frame_94.jpg to data/filter-frame-similarity-groups/Otakudesu.io_Komisan--12_End_720p_frame_94.jpg
# INFO:root:Moving from data/filter-frame/All Out - Tackle Highlight_frame_20.jpg to data/filter-frame-similarity-groups/All Out - Tackle Highlight_frame_20.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_152.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_152.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_907.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_907.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_1644.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_1644.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_BnR--12_End_720p_frame_523.jpg to data/filter-frame-similarity-groups/Otakudesu_BnR--12_End_720p_frame_523.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_21.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_21.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_GJ-bu--12_End_720p_frame_497.jpg to data/filter-frame-similarity-groups/Otakudesu_GJ-bu--12_End_720p_frame_497.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_GJ-bu--12_End_720p_frame_30.jpg to data/filter-frame-similarity-groups/Otakudesu_GJ-bu--12_End_720p_frame_30.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.io_Komisan--12_End_720p_frame_416.jpg to data/filter-frame-similarity-groups/Otakudesu.io_Komisan--12_End_720p_frame_416.jpg
# INFO:root:Moving from data/filter-frame/Best Of Beavis & Butthead (Part 12)_frame_83.jpg to data/filter-frame-similarity-groups/Best Of Beavis & Butthead (Part 12)_frame_83.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_228.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_228.jpg
# INFO:root:Moving from data/filter-frame/All Out - Tackle Highlight_frame_234.jpg to data/filter-frame-similarity-groups/All Out - Tackle Highlight_frame_234.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_950.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_950.jpg
# INFO:root:Moving from data/filter-frame/Jojos Circus Easy as a pie take a bow Part 3Finale_frame_340.jpg to data/filter-frame-similarity-groups/Jojos Circus Easy as a pie take a bow Part 3Finale_frame
jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_Clnad--OVA_720p_frame_437.jpg to data/filter-frame-similarity-groups/Otakudesu_Clnad--OVA_720p_frame_437.jpg
# INFO:root:Moving from data/filter-frame/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_292.jpg to data/filter-frame-similarity-groups/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_292.jpg
# INFO:root:Moving from data/filter-frame/Walt Disney - Pinocchio (Part1)_frame_2159.jpg to data/filter-frame-similarity-groups/Walt Disney - Pinocchio (Part1)_frame_2159.jpg
# INFO:root:Moving from data/filter-frame/Walt Disney - Pinocchio (Part1)_frame_1549.jpg to data/filter-frame-similarity-groups/Walt Disney - Pinocchio (Part1)_frame_1549.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_GJ-bu--12_End_720p_frame_254.jpg to data/filter-frame-similarity-groups/Otakudesu_GJ-bu--12_End_720p_frame_254.jpg
# INFO:root:Moving from data/filter-frame/Kim Possible - Episode 3_frame_112.jpg to data/filter-frame-similarity-groups/Kim Possible - Episode 3_frame_112.jpg
# INFO:root:Moving from data/filter-frame/Kim Possible - Episode 3_frame_113.jpg to data/filter-frame-similarity-groups/Kim Possible - Episode 3_frame_113.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_BnR--12_End_720p_frame_35.jpg to data/filter-frame-similarity-groups/Otakudesu_BnR--12_End_720p_frame_35.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu_BnR--12_End_720p_frame_298.jpg to data/filter-frame-similarity-groups/Otakudesu_BnR--12_End_720p_frame_298.jpg
# INFO:root:Moving from data/filter-frame/Walt Disney - Pinocchio (Part1)_frame_573.jpg to data/filter-frame-similarity-groups/Walt Disney - Pinocchio (Part1)_frame_573.jpg
# INFO:root:Moving from data/filter-frame/Walt Disney - Pinocchio (Part1)_frame_185.jpg to data/filter-frame-similarity-groups/Walt Disney - Pinocchio (Part1)_frame_185.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_606.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_606.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.io_Komisan--12_End_720p_frame_162.jpg to data/filter-frame-similarity-groups/Otakudesu.io_Komisan--12_End_720p_frame_162.jpg
# INFO:root:Moving from data/filter-frame/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_1076.jpg to data/filter-frame-similarity-groups/FULL EPISODE The Eds Are Coming  Ed Edd n Eddy  Cartoon Network_frame_1076.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.net_BLk--24_End_720p_frame_1920.jpg to data/filter-frame-similarity-groups/Otakudesu.net_BLk--24_End_720p_frame_1920.jpg
# INFO:root:Moving from data/filter-frame/MASH-UP Ready to Play Bring Out Your Beast  Craig of The Creek  Cartoon Network_frame_377.jpg to data/filter-frame-similarity-groups/MASH-UP Ready to Play Bring Out Your Beast  Craig of The Creek  Cartoon Network_frame_377.jpg
# INFO:root:Moving from data/filter-frame/Otakudesu.io_Komisan--12_End_720p_frame_314.jpg to data/filter-frame-similarity-groups/Otakudesu.io_Komisan--12_End_720p_frame_314.jpg
# INFO:root:Similarity filtering and grouping is complete.

# %% [markdown]
# gpu then cpu, if gpu is running out of memory

# %%
import tensorflow as tf
from PIL import Image
import os
import shutil

# Define the directories
source_dir = 'filter-frame'
target_dir = 'filter-frame-similarity-groups'

# Create the target directory if it doesn't exist
if not os.path.exists(target_dir):
    os.makedirs(target_dir)

# Function to convert image to vector
def image_to_vector(image_path):
    image = Image.open(image_path)
    image = image.resize((100, 100)) # resizing the image
    image_array = tf.convert_to_tensor(image) # Convert to tensor
    image_array = tf.image.convert_image_dtype(image_array, tf.float32) # Normalize to [0, 1]
    return tf.reshape(image_array, [-1])

# Read images and convert to vectors
image_vectors = []
image_paths = []
for filename in os.listdir(source_dir):
    if filename.endswith(".jpg"):
        image_path = os.path.join(source_dir, filename)
        image_paths.append(image_path)
        image_vectors.append(image_to_vector(image_path))

# Calculate similarities and group images
threshold = 0.9 # similarity threshold
groups = []
while image_vectors:
    first_image = image_vectors.pop(0)
    group = [image_paths.pop(0)]
    i = 0
    while i < len(image_vectors):
        vector = image_vectors[i]
        similarity = tf.reduce_mean(tf.keras.losses.cosine_similarity([first_image], [vector]))
        if similarity >= threshold:
            group.append(image_paths.pop(i))
            image_vectors.pop(i)
        else:
            i += 1
    groups.append(group)

# Move the similar images to the target directory, retaining the first in each group
for group in groups:
    for image_path in group[1:]: # Skip the first image in the group
        shutil.move(image_path, os.path.join(target_dir, os.path.basename(image_path)))

print("Similarity filtering and grouping is complete.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 40
#      38 while i < len(image_vectors):
#      39     vector = image_vectors[i]
# ---> 40     similarity = tf.reduce_mean(tf.keras.losses.cosine_similarity([first_image], [vector]))
#      41     if similarity >= threshold:
#      42         group.append(image_paths.pop(i))
#
# File ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py:2721, in reduce_mean(input_tensor, axis, keepdims, name)
#    2668 """Computes the mean of elements across dimensions of a tensor.
#    2669
#    2670 Reduces `input_tensor` along the dimensions given in `axis` by computing the
#    (...)
#    2715 @end_compatibility
#    2716 """
#    2717 keepdims = False if keepdims is None else bool(keepdims)
#    2718 return _may_reduce_to_scalar(
#    2719     keepdims, axis,
#    2720     gen_math_ops.mean(
# -> 2721         input_tensor, _ReductionDims(input_tensor, axis), keepdims,
#    2722         name=name))
#
# File ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py:2230, in _ReductionDims(x, axis)
#    2228 # Fast path: avoid creating Rank and Range ops if ndims is known.
#    2229 if x_rank:
# -> 2230   return constant_op.constant(np.arange(x_rank, dtype=np.int32))
#    2231 else:
#    2232   # Otherwise, we rely on Range and Rank to do the right thing at run-time.
#    2233   return range(0, array_ops.rank(x))
#
# File ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:263, in constant(value, dtype, shape, name)
#     166 @tf_export("constant", v1=[])
#     167 def constant(value, dtype=None, shape=None, name="Const"):
#     168   """Creates a constant tensor from a tensor-like object.
#     169
#     170   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     261     ValueError: if called on a symbolic tensor.
#     262   """
# --> 263   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     264                         allow_broadcast=True)
#
# File ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:275, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     273     with trace.Trace("tf.constant"):
#     274       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 275   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     278     value, dtype, shape, name, verify_shape, allow_broadcast
#     279 )
#     280 return const_tensor
#
# File ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:285, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     283 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     284   """Creates a constant on the current device."""
# --> 285   t = convert_to_eager_tensor(value, ctx, dtype)
#     286   if shape is None:
#     287     return t
#
# File ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:98, in convert_to_eager_tensor(value, ctx, dtype)
#      96     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97 ctx.ensure_initialized()
# ---> 98 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# better code

# %%
import tensorflow as tf
import os
import shutil

source_dir = 'filter-frame'
target_dir = 'filter-frame-similarity-groups'

if not os.path.exists(target_dir):
    os.makedirs(target_dir)

def load_and_process_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image)
    image = tf.image.resize(image, (100, 100))
    image = tf.image.convert_image_dtype(image, tf.float32)
    return image_path, tf.reshape(image, [-1])

image_paths_ds = tf.data.Dataset.list_files(os.path.join(source_dir, "*.jpg"))
image_vectors_ds = image_paths_ds.map(load_and_process_image, num_parallel_calls=tf.data.AUTOTUNE)

image_vectors = []
image_paths = []
for path, vector in image_vectors_ds.as_numpy_iterator():
    image_vectors.append(vector)
    image_paths.append(path.decode())

threshold = 0.9
groups = []
while image_vectors:
    first_image = image_vectors.pop(0)
    group = [image_paths.pop(0)]
    i = 0
    while i < len(image_vectors):
        vector = image_vectors[i]
        similarity = tf.reduce_mean(tf.keras.losses.cosine_similarity([first_image], [vector]))
        if similarity >= threshold:
            group.append(image_paths.pop(i))
            image_vectors.pop(i)
        else:
            i += 1
    groups.append(group)

for group in groups:
    for image_path in group[1:]:
        shutil.move(image_path, os.path.join(target_dir, os.path.basename(image_path)))

print("Similarity filtering and grouping is complete.")
# Out:
# 2023-08-11 23:42:25.556113: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 23:42:25.569891: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 23:42:25.570435: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 23:42:25.571568: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 23:42:25.571939: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 23:42:25.572220: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 23:42:25.852759: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 23:42:25.853149: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 23:42:25.853439: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 23:42:25.853773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10970 MB memory:  -> device: 0, name: NVIDIA TITAN Xp, pci bus id: 0000:01:00.0, compute capability: 6.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1333782/1951356361.py in ?()
#      31     group = [image_paths.pop(0)]
#      32     i = 0
#      33     while i < len(image_vectors):
#      34         vector = image_vectors[i]
# ---> 35         similarity = tf.reduce_mean(tf.keras.losses.cosine_similarity([first_image], [vector]))
#      36         if similarity >= threshold:
#      37             group.append(image_paths.pop(i))
#      38             image_vectors.pop(i)
#
# ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1173
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
#    1176         return dispatch_target(*args, **kwargs)
# -> 1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179         # TypeError, when given unexpected types.  So we need to catch both.
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/miniconda3/envs/faiss/lib/python3.10/site-packages/keras/src/losses.py in ?(y_true, y_pred, axis)
#    2734     Returns:
#    2735       Cosine similarity tensor.
#    2736     """
#    2737     y_true = tf.linalg.l2_normalize(y_true, axis=axis)
# -> 2738     y_pred = tf.linalg.l2_normalize(y_pred, axis=axis)
#    2739     return -tf.reduce_sum(y_true * y_pred, axis=axis)
#
# ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1173
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
#    1176         return dispatch_target(*args, **kwargs)
# -> 1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179         # TypeError, when given unexpected types.  So we need to catch both.
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     572                 _call_location(), decorator_utils.get_qualified_name(func),
#     573                 func.__module__, arg_name,
#     574                 'in a future version' if date is None else ('after %s' % date),
#     575                 instructions)
# --> 576       return func(*args, **kwargs)
#
# ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/ops/nn_impl.py in ?(x, axis, epsilon, name, dim)
#     702       norm_real = math_ops.multiply(math_ops.real(x), x_inv_norm)
#     703       norm_imag = math_ops.multiply(math_ops.imag(x), x_inv_norm)
#     704       return math_ops.complex(norm_real, norm_imag, name=name)
#     705     square_sum = math_ops.reduce_sum(math_ops.square(x), axis, keepdims=True)
# --> 706     x_inv_norm = math_ops.rsqrt(math_ops.maximum(square_sum, epsilon))
#     707     return math_ops.multiply(x, x_inv_norm, name=name)
#
# ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/ops/gen_math_ops.py in ?(x, y, name)
#    6181         _ctx, "Maximum", name, x, y)
#    6182       return _result
#    6183     except _core._NotOkStatusException as e:
#    6184       _ops.raise_from_not_ok_status(e, name)
# -> 6185     except _core._FallbackException:
#    6186       pass
#    6187     try:
#    6188       _result = _dispatcher_for_maximum(
#
# KeyboardInterrupt:

# %% [markdown]
# cpu

# %%
import tensorflow as tf
import os
import shutil

# Configure TensorFlow to use all available CPU resources
num_threads = os.cpu_count() # Get the number of available CPU cores
tf.config.threading.set_inter_op_parallelism_threads(num_threads)
tf.config.threading.set_intra_op_parallelism_threads(num_threads)

source_dir = 'filter-frame'
target_dir = 'filter-frame-similarity-groups'


if not os.path.exists(target_dir):
    os.makedirs(target_dir)

def load_and_process_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image)
    image = tf.image.resize(image, (100, 100))
    image = tf.image.convert_image_dtype(image, tf.float32)
    return image_path, tf.reshape(image, [-1])

image_paths_ds = tf.data.Dataset.list_files(os.path.join(source_dir, "*.jpg"))
image_vectors_ds = image_paths_ds.map(load_and_process_image, num_parallel_calls=tf.data.AUTOTUNE)

image_vectors = []
image_paths = []
for path, vector in image_vectors_ds.as_numpy_iterator():
    image_vectors.append(vector)
    image_paths.append(path.decode())

threshold = 0.9
groups = []
while image_vectors:
    first_image = image_vectors.pop(0)
    group = [image_paths.pop(0)]
    i = 0
    while i < len(image_vectors):
        vector = image_vectors[i]
        similarity = tf.reduce_mean(tf.keras.losses.cosine_similarity([first_image], [vector]))
        if similarity >= threshold:
            group.append(image_paths.pop(i))
            image_vectors.pop(i)
        else:
            i += 1
    groups.append(group)

for group in groups:
    for image_path in group[1:]:
        shutil.move(image_path, os.path.join(target_dir, os.path.basename(image_path)))

print("Similarity filtering and grouping is complete.")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 7
#       5 # Configure TensorFlow to use all available CPU resources
#       6 num_threads = os.cpu_count() # Get the number of available CPU cores
# ----> 7 tf.config.threading.set_inter_op_parallelism_threads(num_threads)
#       8 tf.config.threading.set_intra_op_parallelism_threads(num_threads)
#      10 source_dir = 'filter-frame'
#
# File ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/framework/config.py:144, in set_inter_op_parallelism_threads(num_threads)
#     134 @tf_export('config.threading.set_inter_op_parallelism_threads')
#     135 def set_inter_op_parallelism_threads(num_threads):
#     136   """Set number of threads used for parallelism between independent operations.
#     137
#     138   Determines the number of threads used by independent non-blocking operations.
#    (...)
#     142     num_threads: Number of parallel threads
#     143   """
# --> 144   context.context().inter_op_parallelism_threads = num_threads
#
# File ~/miniconda3/envs/faiss/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1962, in Context.inter_op_parallelism_threads(self, num_threads)
#    1959   return
#    1961 if self._context_handle is not None:
# -> 1962   raise RuntimeError(
#    1963       "Inter op parallelism cannot be modified after initialization.")
#    1965 self._inter_op_parallelism_threads = num_threads
#
# RuntimeError: Inter op parallelism cannot be modified after initialization.
